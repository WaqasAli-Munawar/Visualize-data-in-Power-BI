# %% [markdown]
# Organizations use reports to monitor and record performance and identify trends and variances. When an organization is making decisions, it relies on the information that is provided by reports. Reports drive organizational behavior and action, at every level, in every aspect.
#
# After we've added visuals to our report and designed them for accessibility, we can make further improvements by adding interactivity to the report before finally sharing it with the report audience. In this module, we'll apply the available functions in the report editor in Power BI Desktop to our visuals, which will transform our report into a data-driven story. We'll provide users tools so they can further explore the information that we present in our visuals. Then, we'll publish the report so users can access the information that they need to make decisions.
#
# We have already begun adding and customizing visuals on the report. Now, we need to take the report to the next level to meet management's requirements. By the end of this file, we will be able to:
#
# * Add buttons, bookmarks, and selections.
# * Design report navigation.
# * Use basic interactions.
# * Use advanced interactions and drillthrough.
# * Configure conditional formatting.
# * Apply slicing, filtering, and sorting.
# * Publish and export reports.
# * Comment on reports.
# * Use Performance analyzer to tune reports.
# * Optimize reports for mobile use.

# %% [markdown]
# We can use the **Bookmarks**, **Buttons**, and **Selections** features in Power BI Desktop to make our report more compelling, interactive, and simpler for users to navigate.
#
# * **Bookmarks** - Capture the currently configured view of a report page so we can quickly return to that view later. We can use bookmarks for different reasons. For example, we can use them to keep track of our own progress when creating reports. We can also use them to build a PowerPoint-like presentation that goes through the bookmarks in order, thereby telling a story with our report.
# * **Buttons** - Create a more interactive experience for the report users. With the addition of buttons that have assigned actions, our report behaves similar to an app, where users can hover, select, and interact more with the content.
# * **Selections** - Allow we to determine what items in the report are visible and what items are hidden. Selections are used alongside bookmarks and buttons.

# %% [markdown]
# Consider a situation where we have designed a report page and want to have a second page that looks almost the same, except that one of the visuals will be different. Rather than creating a second page and manually making changes, we can use a combination of selections, bookmarks, and buttons to switch between the two visuals on one page.
#
# **Add bookmarks**
#
# When we add a bookmark, the following elements are saved with it:
#
# * Current page
# * Filters
# * Slicers, including slicer type (for example, drop-down or list) and slicer state
# * Visual selection state (such as cross-highlight filters)
# * Sort order
# * Drill location
# * Visibility of an object (by using the Selection pane)
# * Focus or Spotlight modes of any visible object

# %% [markdown]
# In this example, we see how to add bookmarks to allow users to switch between two visuals on one page. First, we need to set up how we want the page to initially display.
#
# When we have added and formatted all the visuals and other items on the page, we can add a bookmark to capture a snapshot of the page in its current state.
#
# Before adding a bookmark, you go to the View tab in the ribbon and select Selection. The displayed Selection pane includes a list of all items on your page, along with an eye icon that indicates the items that are currently visible. You can rename the items in the list by double-clicking them so you clearly know which one is which.
#
# Now we are ready to add the bookmark. On the **View** tab, select **Bookmarks**. On the Bookmarks panel that displays, select **Add**. It's good practice to rename the new bookmark so its purpose is clear; this notion is especially true if we plan on adding multiple bookmarks. To rename a bookmark, double-click the bookmark and enter the new name.

# %% [markdown]
# In this example, we want to change the bookmark name from Bookmark 1 to Variance Chart because the Variance chart is the main focus of the page, as shown in the following image. In the **Selection** pane, the Variance chart displays and the other visuals are hidden.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Next, we can add the second bookmark. Start by making changes to how the page currently appears. In this example, we will add another bookmark for the main dashboard charts. Because we only want to see charts from the main dashboard, we can hide the Variance chart by selecting its eye icon on the **Selections** pane. Then, add a bookmark for this new view of the page and rename it as Main Dashboard.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Now, we can switch between the two bookmarks to see the difference in the page.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Repeat these steps to add more bookmarks. In summary, we would select items that we want to show/hide on the report page, add a bookmark, and then give it a descriptive name. We can now assign those bookmarks to buttons so that users can switch between the bookmarks.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# We can use buttons for many reasons, such as to switch between two visuals in a report (as required in the previous example), to drill down into the data in a visual, or to move from one page in our report to another. Power BI Desktop provides a range of button types that we can add to our report, as illustrated in the following image.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# In this example, we see how to add customized buttons that are used to switch between two bookmarks. To add a button, go to the **Insert** tab on the ribbon and select **Buttons**. Then, select the type of button that we want to add from the list, which in this case, we would select the **Blank** option.
#
# When the button is added to the page, reposition the button to above the visual on the right side. Next, select the button and then, in the **Visualizations** pane, move the **Button** Text slider to the **On** position. Expand the **Button Text** section, and then enter the text that we want to display on the button, for example, **Main Dashboard**. We can then format the button text by changing its font, color, alignment, and text size. Expand the **Background** section and select a suitable color for the button.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Now, we can add an action to the button. Go to the **Action** slider near the bottom of the **Visualizations** pane and move the slider to the **On** position. Then, expand the **Actions** section to view the options. The options for the button action types are as follows, some of which are explained in more detail in the subsequent sections.
#
# * `Back` - Returns the user to the previous page of the report. This option is useful for drillthrough pages or pages that are accessed from one main page.
# * `Bookmark` - Presents the report page that's associated with a bookmark that is defined for the current report.
# * `Drill through` - Brings the user to a drillthrough page that is filtered to their selection, without using bookmarks.
# * `Page navigation` - Brings the user to a different page within the report, also without using bookmarks, which is an effective way to create a navigation experience for our report users. This type of button is discussed later in this module.
# * `Q&A` - Opens a Q&A Explorer window, where users can enter questions to quickly find the information that they are looking for and specify the type of visual that they want to see the information displayed in. This option can be useful if we want to save space in the report but still offer Q&A functionality to the user.
# * `Web URL` - Opens a website in a new browser window. For example, we might want to give users quick access to our organization's website or intranet from within a report.

# %% [markdown]
# In this example, we select **Bookmark** as the action type. In the **Bookmark** list that displays, select the bookmark that we want to assign to the action, the **Main Dashboard** bookmark that we created previously. For enhanced accessibility, we should add a tooltip that users will see when they hover over the button, but in this case, it's not required because we have a descriptive button label.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Now that our button is set up, we can copy and paste the button so that we have two buttons with consistent formatting on the page. In this example, we rename the second button to **Variance Chart** and change the assigned action to the **Variance Chart** bookmark.
#
# We can then reposition the buttons anywhere on our canvas. For this example, we will position the new buttons on the left side of the canvas for easy navigation.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Our buttons are now ready for use. We can use them to switch between two bookmarks with a different layout on the same page. When we select the **Main Dashboard** button, the main dashboard charts display, and when we select the **Variance Chart** button, the **Variance chart** displays.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Report navigation is the way in which our report users move from one page in our report to the next, move from one visual to another, and return to where they started. The design of our report navigation is important because, if users can't easily find their way around in our reports, they will become frustrated and will have a negative experience.
#
# We can use a range of buttons and bookmarks when designing our report navigation, and we can further enhance this navigation experience with the use of conditional formatting.
#
# Before we do that, complete the exercises below to add a few additional pages and visuals to the report. This will set up the exercises for the rest of the file. We can add a page to our report by clicking the `+` button at the buttom of the page.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Add navigation buttons**
#
# To design the navigation within our report, we can create a new **Navigation page** in our report and add navigation buttons on that page. We can also use a combination of both options. When users select one of these buttons, they are brought directly to a different page within the report, which we can hide so that it can only be accessed through the **Navigation page buttons**.
#
# In the following example, we'll see how create a **Navigation page** on which we can add two navigation buttons to our other pages.
#
# Start by adding a button, as we did previously. This time, however, when we expand the **Actions** section in the **Visualizations** pane, select **Page navigation** as the action type, and then select the page in our report that is the **Destination** for the button.
#
# When we have set up the first navigation button, copy and paste that button to create the second navigation button so we preserve the formatting that we applied to the first button. Then, change the title and destination for the second button.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# When we select a button, we will be brought directly to the assigned page destination. When we are on that destination page, to return to the **Navigation** page, we can use one of the following **Back** button navigation options:
#
# * Select the **Back** button from the main **Buttons** menu, and then reposition the button to where we want it to sit on the page.
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# * Select the **Blank** button from the main **Buttons** menu, reposition and customize the button as required, and then select **Back** as the action type.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **Set the navigation destination**
#
# We can use conditional formatting to set the navigation destination based on the output of a measure. One reason that we might want to use this type of navigation method is to save space in our report. For example, rather than using multiple navigation buttons (as illustrated in the previous image), we can use a single button to navigate to different pages based on the user's selection (as illustrated in the following image).
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Other reasons for using this type of navigation include:
#
# * To specify the logical path that our report users should take. In other words, we determine the order in which users view each page.
# * To tell a data-driven story. For example, we could use it to give our employees a message that is backed up by the data. This method could be useful to help drive change, such as increase sales.
# * To create a reporting portal where users can navigate to a set of reports

# %% [markdown]
# To use conditional formatting to set the navigation, start by creating a single-column table that contains the names of the navigation destinations. In the table, ensure that the entered values match our report page names.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# When we load the table, add it to the report page as a single-select slicer. Next, add a page navigation button. In the Actions section, ensure that `None` is set as the **Destination**, right-click the destination, and then select **Conditional formatting**.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# On the Destination window, select the name of the column that we created. Notice that, based on the user's selection, the button can navigate to different pages. Configure the conditional formatting to complete our navigation design.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# In Power BI Desktop, our report is dynamic. When we make a selection on one visual in the report, other visuals might change to reflect that selection. Similarly, if hierarchies are in our data, we can move up and down the hierarchy to see the data at different levels. The following sections explain how the basic interactions work and how we can use hierarchies in our visuals.

# %% [markdown]
# **View interactions**
#
# When multiple visuals exist on the same report page, they all interact with each other. For that reason, we should become familiar with these interactions to see how our report changes. Compare the following two images. In the first image, the data displays at a high level.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# When we select an element in a visual, such as Components in the Product Category visual, the other visuals update to reflect our selection, as illustrated in the second image.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# When we have become familiar with the interactions, we might want to make changes to control how those interactions flow between the visuals. This process is further explained later in this module.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# A **hierarchy** is a structure in which groups are ranked one above the other according to a specific status. Think of your own organizational hierarchy, where
# * The CEO is at the top level,
# * then managers in the middle level, and
# * employees at the lower level.
#
# Similarly, we'll likely have hierarchies for our data in Power BI. For example, we could have a time hierarchy with levels such as
# * year,
# * quarter,
# * month, and
# * day, or
# * a product hierarchy with levels such as category, subcategory, and product.

# %% [markdown]
# Regarding dates, Power BI creates hierarchies automatically. When we select the hierarchy in the **Fields** pane, the date hierarchy is added to the **Axis** field on the **Visualizations** pane and a blank visual is created for us, which is ready for additional fields. The hierarchy icons are located above the visual, as illustrated in the following image.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# When we add another field to the visual, the visual becomes useful, and we can then use the hierarchy icons to navigate through the hierarchy. Power BI creates a predefined drill path for the data. In the following image, the Gross Sales field was added to the visual and we can see the data at the highest level (year). Then, when the Expand all down one level in the hierarchy button was selected, the hierarchy was expanded down by one level (quarter). If we were to select the button again, the visual would update to display the next lower level in the hierarchy (month), and so on.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Another navigation option is the Go to the next level in the hierarchy button. When we select either hierarchy option, select the **Drill** up button to move back up the hierarchy.
#
# The default date hierarchy feature in Power BI is quick and simple to use. However, if we have our own date table, we can use it to create the hierarchy instead. In the following image, the **Year, Month, Quarter, and Day** fields were added to the **Axis** field well on the **Visualizations** pane. The data result is the same as the default hierarchy, so we can navigate through the hierarchy in the same way.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# We can also predefine the hierarchy path for our report users to remove any guesswork. For example, we might want to prevent users from viewing a particular hierarchy level. To do so, remove all fields from the **Axis** well and then, in the **Fields** pane, right-click the field that we want to set as the top level of the hierarchy and select New hierarchy. The new hierarchy displays in the list in the **Fields** pane. We can now drag and drop other fields into the new hierarchy or right-click each field and select **Add** to hierarchy.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Ensure that our visual is selected, and then select the **New** hierarchy field in the **Fields** pane to apply it to the visual.
#
# ![image.png](attachment:image.png)
#
# We can use the hierarchy buttons above the visual to expand the hierarchy and drill back up again.

# %% [markdown]
# **Edit interactions**
#
# We can use visual interaction controls to customize how the visualizations on our report page impact each other, in other words, filter and highlight each other. This won't be covered in detail in this course, but we can read more about how to do this at [MS Learn](https://docs.microsoft.com/en-us/learn/modules/data-driven-story-power-bi/6-advanced-interactions).

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# We can use the **Drill through feature** to create a page in our report that focuses on a specific entity, such as a product, category, or region. We can then access this page when we drill through from the related visuals that are on other pages in our report. The information that displays on the drillthrough page will be specific to the item that we select on the visual, as illustrated in the following image.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# In this example, we will see how to create a drillthrough for the product category entity. We can start by creating a page in our report and rename it to **Details Page**. On that page, we will add a visual for the entity that we want to provide the drillthrough for (a table that displays data for the Category, SubCategory, Country, Gross Sales, and Net Sales fields).
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Then, from the **Values** section of the **Visualizations** pane, drag the **field** (Category Name) for which we want to enable drillthrough in the **Drill through filters** as well.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Ensure that the Keep all filters option is set to **ON**, so when we drill through from a visual, the same filters will be applied on the Details page.
#
# Power BI Desktop automatically creates a **Back** button visual on the page for us. This button is for navigation purposes, so our report users can return to the report page from which they came. We can reposition and resize this button on the report page or replace it with our own type of button.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# To use drillthrough, right-click a data point on a visual in another report page, select **Drill through**, and then select the **focused page** (Details page) to get details that are filtered to that context.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **Cross-report drillthrough**
#
# The Cross-report drillthrough feature allows us to contextually jump from one report to another report in the same Power BI service workspace or app. This feature allows us to connect two or more reports that have related content. We can also pass filter context along with that cross-report connection. This won't be covered in detail in this course, but we can read more about how to do this at [MS Learn](https://docs.microsoft.com/en-us/learn/modules/data-driven-story-power-bi/6-advanced-interactions).

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Conditional formatting in Power BI Desktop allows us to specify customized cell colors, including color gradients, that are based on field values. Additionally, we can use conditional formatting to represent cell values with data bars, KPI icons, or active web links.
#
# We might want to use conditional formatting to highlight or differentiate the data that is displayed in our visual. This approach will help us and other users see key data insights easily.
#
# For example, we could set up conditional formatting for our sales figures. If the sales amount falls below zero, we could display this value in red, a color that is associated with danger, so that users will see it clearly and know that they need to take immediate action. Conversely, we could set a value for our sales target, displaying amounts over that target amount in a green color to signify that the target is met and all is going well.
#
# The following example shows conditional formatting being used in two visuals, Table and Matrix, where it is possible to set different conditions on a column. We can apply conditional formatting to any text or data field, but the formatting needs to be based on a field that has numeric, color name or hex code, or web URL values.

# %% [markdown]
# In this example, we will select the table visualization and then, in the **Format** pane, expand the **Conditional formatting** section. Turn on the **Background color** option, and then select the **Advanced controls** option. In the window that displays, set a condition to change background color to red for cells that have low values and green for cells with high values.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# The Power BI conditional formatting function will automatically detect the highest and the lowest number in each column and will apply background coloring according to the values.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# If we want to remove the conditional formatting that we set, select the **Values** tab on the **Visualizations** pane and right-click the value (field) that we set the formatting for. Select **Remove conditional formatting** and then select the type of formatting that we want to remove, for example **All** or **Background** color.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Power BI Desktop provides three tools that we can use to edit and configure interactions between the visualizations that we add to our report:
# * slicers,
# * filters, and
# * sorting.

# %% [markdown]
# The process of filtering allows us to remove all the data that we don't need, so we can focus on the data that we do need. We can apply filtering directly by using the Filters pane or by adding and using a slicer. Slicers and filters are similar; both let us filter out the unnecessary data. Experiment with both options to see which one is the best mechanism for our report situation. We might decide to use one option over the other or use a combination of both.
#
# Contrary to filtering, the process of sorting allows us to highlight the important information without removing any of the data.

# %% [markdown]
# **Add a slicer**
#
# A slicer is a type of filter that we can add to our report, so users can segment the data in the report by a specific value, such as by year or geographical location. Slicers narrow the portion of the dataset that is shown in the other report visualizations. We can use a slicer to:
#
# * Provide quicker access to commonly used or important filters.
# * Simplify a user's ability to see the current filtered state without having to open a drop-down list.
# * Filter by columns that are unneeded and hidden in the data tables.
# * Create more focused reports (by putting slicers next to important visuals).
# * Defer queries to the data model by using a drop-down slicer, particularly when we are using DirectQuery.
#
# Slicers are not supported for input fields and drilldown functions.
#
# When we add a slicer, we can change it to populate a list of items that we want to use to filter the elements of our page. We can make that list appear in a drop-down format if we want to save space for more important data on our report page. Rather than using a list format, we can turn our slicer into buttons to make it easier for users to filter data. Also, we can use our slicer with date type columns, so we can select a different data range by using the slider.

# %% [markdown]
# To apply a slicer, select the **Slicer** icon in the **Visualizations** pane. Then, in the **Fields** pane, select the fields that we want to include in the slicer or drag them into the slicer visualization.
#
# The visualization then changes to a list of items (filters) with check boxes that we can use to segment the data. When we select an item's check box, Power BI will filter (slice) all the other visualizations on the same report page, as illustrated in the following image.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# We can add as many slicers as we want to a report page. If we use a list type of slicer, we can configure the selection controls. Select the slicer and then, in the **Format** pane, expand the **Selection controls section** to view the following options:
#
# * `Single select` - This option is Off by default. It ensures that only one item can be selected at a time.
# * `Multi-select with CTRL` - This option is On by default. It allows you to select multiple items by pressing the Ctrl key.
# * Show `Select all` - This option is Off by default. If we turn on this option, a **Select all** check box is added to the slicer. We might want to add this option so that we can quickly select or clear all items in the list. If we select all items, selecting an item will clear it, allowing an is-not type of filter.

# %% [markdown]
# While slicers are useful, if we want to filter our data in a basic way, we don't need to add slicers to our report. Power BI Desktop has a **Filters** pane that can handle the basic slicer operations. Therefore, depending on our requirements, we might save time and effort by avoiding the use of slicers and using the **Filters** pane instead. By using this pane, we can reduce the total number of visuals on a report, which will improve performance.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# From the report user's perspective, the **Filters** pane contains filters that we, the report designer, have added to the report. The filters allow users to interact with the visuals at the report, page, and visual level.

# %% [markdown]
# As a report designer, we can customize the **Filters** pane in Power BI Desktop as follows:
#
# * Add and remove fields to filter on.
# * Change the filter state.
# * Format and customize the **Filters** pane so that it seems part of our report.
# * Define whether the **Filters** pane is open or collapsed by default when a consumer opens the report.
# * Hide the entire **Filters** pane or specific filters that we don't want report consumers to see.
# * Control and bookmark the visibility, open, and collapsed state of the **Filters** pane.
# * Lock filters that we don't want consumers to edit.

# %% [markdown]
# We can expand and collapse the **Filters** pane so that we can hide it when we do not need it. When we expand the **Filters** pane, depending on the item in the report that we have selected, we will see the following sections:
#
# * Filters on this visual - Filters that apply to the selected visual and nothing else. This section only displays if we have a visual selected.
# * Filters on this page - Filters that apply to the whole page that we currently have open.
# * Filters on all pages - Filters that apply to all the pages in our report.
# * Drillthrough - Filters that apply to a single entity in a report.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# To apply a filter, drag and drop a field from the **Fields** pane into the relevant section of the **Filter** pane.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# We can sort the data that is displayed in our visuals so it's displayed to our specifications.
#
# Sorting helps us display the most important data in the most logical way, such as in alphabetical or numeric order. This basic feature can help when we are making significant business decisions. For example, if we display products with the highest sales first, we are helping users see which product is the most popular among the customer base. Similarly, the products with low sales can be discontinued or replaced with new products to help increase revenue.

# %% [markdown]
# To sort a visual, start by selecting the **More options**... button in the upper-right corner of the visual, where we will have three sorting options:
#
# * **Sort descending** - Sorts the visual by the selected column in the order of greatest value to smallest value.
# * **Sort ascending** - Sorts the visual by the selected column in the order of smallest value to greatest value.
# * **Sort by** - Sorts the data by a specific column. Hover over this option to display the list of columns that we can select from.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# When we are finished designing our report, we can publish it to our workspace in Power BI Service. We also have options to export to Microsoft Excel.

# %% [markdown]
# **Publish reports**
#
# When we publish a report, Power BI Desktop packages our report and data, including all our visualizations, queries, and custom measures, and then uploads them to Power BI service.
#
# To publish our report, select the **Publish** button on the **Home** tab.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# We might be prompted to save our changes, in which case, we select **Save** and then proceed to save our Power BI (`.pbix`) file.
#
# We might also be required to sign in to Power BI. If so, we can enter our sign-in credentials to continue. If we don't have a Power BI account, we can create one. To creat a new account, we'll need to use a company or school email address. If we don't have a company or school email address, we can follow these [instructions](https://docs.microsoft.com/en-us/power-bi/admin/service-admin-signing-up-for-power-bi-with-a-new-office-365-trial) provided by Microsoft to first create an new email account, and then a new Power BI account.

# %% [markdown]
# In the **Publish to Power BI** window, select the destination in which we want to publish the report. For example, we can publish to a workspace within Power BI. For production reports, we recommend that we publish to an app workspace.
#
# When the report is successfully published, we'll get a success message that contains a link to our report in our Power BI site. Select Got it to close the Publishing to BI window and return to the report in Power BI Desktop. From the report page, we can select the provided URL to go to Power BI service and see our new report.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Export reports**
#
# Power BI allows us to export visual data, reports, and datasets. We can export to several different formats including
# * CSV,
# * Excel, and
# * PDF.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# When we publish our report to Power BI web service, the consumers of our report can add comments to it. Comments can be useful for personal comments or for starting a conversation about a report item with our colleagues. For example, users can comment on pages or visuals that they are experiencing issues with, or they could give us suggestions for changes or improvements.
#
# Comments are also available for paginated reports, dashboards, and visuals. Anyone with the right permissions can see those comments. When we add a comment to a specific visual rather than the report as a whole, the context of the comment is clearer and acts like a personal bookmark.
#
# To add or view comments on a report, open the report in Power BI web service. In the upper-right corner, select **Comments**. In the **Comments** pane, we can view existing comments and write our own comments, and then select **Post Comment**.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# To add a comment from a visual, select the visual in the report to open it in focus mode. Select **Comments** from the top menu and enter your comment in the **Comments** pane that displays.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# When we have finished creating our report, the performance of that report depends on how quickly data can load onto the report page. We should test our report in the Power BI Report Server to see how it works from a user's perspective. We may want to optimize our reports for use on mobile devices. If we experience issues, or if the report users have reported issues, we need to investigate the cause of those issues and take measures to tune the report for more optimized performance.
#
# Performance optimization is outside the scope of this file. We can read more about it at [MS Learn](https://docs.microsoft.com/en-us/learn/modules/data-driven-story-power-bi/11-tune-reports).

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Power BI Desktop report editor provides the tools that we need to create a concise, well-designed report that displays information in a compelling and user-friendly, accessible way. Along with creating this well-designed report, in this lesson, we were tasked with enhancing the range of visuals on our report to offer more user interaction and detailed information.
#
# We started by considering the best position and size of our visuals and designed the report layout with user accessibility in mind. Next, we applied a selection of buttons, bookmarks, filters, and other elements to make the report more visually pleasing, interactive, and easier to navigate. We then considered the interactions of the visuals in our report and made some changes. We added a variety of slicing, filtering, and sorting techniques to our data so that users could find the information that they needed, at both a high and low detail level. At that stage, we published the report to Power BI Report Server so that it could be accessed by all users.
#
# If we couldn't use Power BI Desktop to produce reports, we would still be able to analyze the data, but we wouldn't be able to communicate our findings. Power BI Desktop does more than enable us to communicate the data; it allows us to design a range of compelling, powerful reports that can be used for telling data-driven stories and helping with decision making at all organizational levels.
